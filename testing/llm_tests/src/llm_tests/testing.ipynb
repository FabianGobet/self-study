# %%
from textwrap import dedent

text: str = dedent("""\
    This is a multiline string.
        It is created using the textwrap.dedent function.
        
    Testing empty lines.\
    """)

print(text)
print('Done.')
# Out:
# This is a multiline string.
#     It is created using the textwrap.dedent function.
#
# Testing empty lines.
# Done.

# %%
from pathlib import Path


isinstance(Path("pyproject.toml"), str)
# Out:
# False

# %%
import litellm

litellm.supports_function_calling(model="deepseek/deepseek-reasoner")
# Out:
# True
