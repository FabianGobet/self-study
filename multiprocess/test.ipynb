# %%
from multiprocessing import Pool
from tmp_func import task

def parallel_task(iterable, num_procs=8):
    
    if __name__ == '__main__':
        with Pool(processes=num_procs) as pool:
            for result in pool.imap_unordered(task, iterable):
                yield result

# %%
data_list = [i for i in range(40)]

for t in parallel_task(data_list):
    print(t)
# Out:
# (6, 2468)
# (0, 2936)
# (4, 22236)
# (5, 2320)
# (9, 2936)
# (8, 2468)
# (12, 2936)
# (1, 13788)
# (11, 2320)
# (2, 3200)
# (10, 22236)
# (7, 5592)
# (3, 15584)
# (14, 2936)
# (19, 5592)
# (13, 2468)
# (20, 15584)
# (23, 2468)
# (21, 2936)
# (18, 22236)
# (17, 3200)
# (26, 2936)
# (15, 13788)
# (16, 2320)
# (27, 22236)
# (32, 22236)
# (25, 2468)
# (34, 2468)
# (22, 5592)
# (24, 15584)
# (31, 2320)
# (29, 2936)
# (37, 15584)
# (28, 3200)
# (36, 5592)
# (30, 13788)
# (35, 2468)
# (33, 22236)
# (38, 2320)
# (39, 2936)
